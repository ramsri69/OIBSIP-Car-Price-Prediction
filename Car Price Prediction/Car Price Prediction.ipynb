# %% [markdown]
# # Importing libraries

# %%
import numpy as np # for performing mathematical calculations behind ML algorithms
import matplotlib.pyplot as plt # for visualization
import pandas as pd # for handling and cleaning the dataset
import seaborn as sns # for visualization

# %% [markdown]
# # Importing the dataset

# %%
dataset = pd.read_csv('CarPrice_Assignment.csv')

# %% [markdown]
# # Analyzing the data

# %%
dataset.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber
# 0       1          3        alfa-romero giulia      gas        std        two  \
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize
# 0  convertible        rwd          front       88.6  ...         130  \
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg
# ...

# %%
dataset.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber
# 200     201         -1  volvo 145e (sw)      gas        std       four  \
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem
# 200   sedan        rwd          front      109.1  ...         141        mpfi  \
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg
# ...

# %%
# Numerical/Statistical analysis of the dataset
dataset.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000  \
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio
# count   205.000000  205.000000  205.000000  205.000000        205.000000  \
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
# Dimensions of dataset
print('There are ',dataset.shape[0],'rows and ',dataset.shape[1],'columns in the dataset.')
# Out:
# There are  205 rows and  26 columns in the dataset.

# %%
# Here we are trying to check that whether this dataset has any duplicate value or not
print('There are',dataset.duplicated().sum(),'duplicate values in the dateset.') #using duplicated() pre-defined function
# Out:
# There are 0 duplicate values in the dateset.

# %%
# Check for NULL values
dataset.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
# Schema of dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# # Getting counts of each categories of columns with Datatype=object

# %%
print(dataset.CarName.value_counts())
print(dataset.fueltype.value_counts())
print(dataset.aspiration.value_counts())
print(dataset.doornumber.value_counts())
print(dataset.carbody.value_counts())
print(dataset.drivewheel.value_counts())
print(dataset.enginelocation.value_counts())
print(dataset.enginetype.value_counts())
print(dataset.cylindernumber.value_counts())
print(dataset.fuelsystem.value_counts())
# Out:
# CarName
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: count, Length: 147, dtype: int64
# fueltype
# gas       185
# diesel     20
# Name: count, dtype: int64
# aspiration
# std      168
# turbo     37
# Name: count, dtype: int64
# doornumber
# four    115
# two      90
# Name: count, dtype: int64
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64
# drivewheel
# fwd    120
# rwd     76
# 4wd      9
# Name: count, dtype: int64
# enginelocation
# front    202
# rear       3
# Name: count, dtype: int64
# enginetype
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# ...

# %% [markdown]
# # 1) Converting String Values to Int using Label Encoder(For Carnames as there are many types of car)

# %% [markdown]
# # 2) Converting the other object types to int with replace

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset['CarName'] = le.fit_transform(dataset['CarName'])
dataset.replace({'fueltype':{'gas':0,'diesel':1}},inplace=True)
dataset.replace({'aspiration':{'std':0,'turbo':1}},inplace=True)
dataset.replace({'doornumber':{'four':0,'two':1}},inplace=True)
dataset.replace({'carbody':{'sedan':0,'hatchback':1,'wagon':2,'hardtop':3,'convertible':4}},inplace=True)
dataset.replace({'drivewheel':{'fwd':0,'rwd':1,'4wd':2}},inplace=True)
dataset.replace({'enginelocation':{'front':0,'rear':1}},inplace=True)
dataset.replace({'enginetype':{'ohc':0,'ohcf':1,'ohcv':2,'dohc':3,'l':4,'rotor':5,'dohcv':6}},inplace=True)
dataset.replace({'cylindernumber':{'four':0,'six':1,'five':2,'eight':3,'two':4,'three':5,'twelve':6}},inplace=True)
dataset.replace({'fuelsystem':{'mpfi':0,'2bbl':1,'idi':2,'1bbl':3,'spdi':4,'4bbl':5,'mfi':6,'spfi':7}},inplace=True)
dataset.head()
# Out:
#    car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody
# 0       1          3        2         0           0           1        4  \
# 1       2          3        3         0           0           1        4
# 2       3          1        1         0           0           1        1
# 3       4          2        4         0           0           0        0
# 4       5          2        5         0           0           0        0
#
#    drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem
# 0           1               0       88.6  ...         130           0  \
# 1           1               0       88.6  ...         130           0
# 2           1               0       94.5  ...         152           0
# 3           0               0       99.8  ...         109           0
# 4           2               0       99.4  ...         136           0
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg
# ...

# %% [markdown]
# # Model Development

# %%
print(x)
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody
# 0         1          3        2         0           0           1        4  \
# 1         2          3        3         0           0           1        4
# 2         3          1        1         0           0           1        1
# 3         4          2        4         0           0           0        0
# 4         5          2        5         0           0           0        0
# ..      ...        ...      ...       ...         ...         ...      ...
# 200     201         -1      139         0           0           0        0
# 201     202         -1      138         0           1           0        0
# 202     203         -1      140         0           0           0        0
# 203     204         -1      142         1           1           0        0
# 204     205         -1      143         0           1           0        0
#
# ...

# %%
print(y)
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %% [markdown]
# # Preparing the Train and Test Data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2,random_state=0)
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (205, 25) (164, 25) (41, 25)

# %% [markdown]
# # Training through different Models

# %% [markdown]
# # 1) Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
model1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_data_prediction1=model1.predict(x_test)

# %%
print(test_data_prediction1)
# Out:
# [ 4697.51933023 17162.03167431 17319.83517961  6141.3059653
#  10293.53524806 12892.6125781   7667.91481306  6628.49434384
#  18656.5530908   6842.50824631 17607.50657628 26145.68791624
#  10631.62633617 14280.33074465  7761.68120978 12558.59577176
#   9113.3947309  21776.62515956  8708.44827702  5944.75670982
#  11071.31427217 16678.72835074  9933.27876987 14412.88796844
#  19738.48672023  7051.80513473  5705.41751383 19111.56935124
#   6499.61252419 11271.90878836  8443.88387801 10733.12013728
#  16916.87986259  9574.94665805  6373.0618868  25730.66570449
#   6930.44809111 13793.35816856  7125.24687609 36012.52425764
#   7571.82324762]

# %%
testing_data_model_score = model1.score(x_test, y_test)
print("Model Score/Performance on Testing data",testing_data_model_score)

training_data_model_score = model1.score(x_train, y_train)
print("Model Score/Performance on Training data",training_data_model_score)
# Out:
# Model Score/Performance on Testing data 0.8197374446024239
# Model Score/Performance on Training data 0.9253844853561265

# %%
df = pd.DataFrame(data={'Predicted value':test_data_prediction1,'Actual Value':y_test})
df
# Out:
#      Predicted value  Actual Value
# 52       4697.519330        6795.0
# 181     17162.031674       15750.0
# 5       17319.835180       15250.0
# 18       6141.305965        5151.0
# 188     10293.535248        9995.0
# 170     12892.612578       11199.0
# 76       7667.914813        5389.0
# 154      6628.494344        7898.0
# 104     18656.553091       17199.0
# 33       6842.508246        6529.0
# 12      17607.506576       20970.0
# 129     26145.687916       31400.5
# 55      10631.626336       10945.0
# 66      14280.330745       18344.0
# 45       7761.681210        8916.5
# 169     12558.595772        9989.0
# 130      9113.394731        9295.0
# 7       21776.625160       18920.0
# 37       8708.448277        7895.0
# 152      5944.756710        6488.0
# 80      11071.314272        9959.0
# 111     16678.728351       15580.0
# 131      9933.278770        9895.0
# 171     14412.887968       11549.0
# 179     19738.486720       15998.0
# 138      7051.805135        5118.0
# ...

# %% [markdown]
# # Model Evaluation(Linear Regression):

# %%
from sklearn.metrics import r2_score
r2Score = r2_score(test_data_prediction1, y_test)
print("R2 score of model is :" ,r2Score*100)
# Out:
# R2 score of model is : 68.44863463333095

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(test_data_prediction1,y_test)
print("Mean Absolute Error is :" ,mae)
# Out:
# Mean Absolute Error is : 2472.6491092636625

# %% [markdown]
# Conclusion
#
# So, the mean absolute error is 2472.6491092636625. Therefore our predicted value can be 2472.6491092636625 units greater than or less than the actual value.

# %% [markdown]
# # 2) RFC (Random Forest Classifier)

# %%
from sklearn.ensemble import RandomForestRegressor
model2= RandomForestRegressor(n_estimators=100, random_state=0)
model2.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
test_data_prediction2=model2.predict(x_test)

# %%
print(test_data_prediction2)
# Out:
# [ 5949.26    16348.26167 14447.3      6031.       9645.03    14529.51
#   5960.81     7599.47    18111.27501  6713.2     19363.57    35765.48
#  12419.68    14392.47     6357.65    13317.46    12210.14    18405.93167
#   8576.26     6565.21     9395.88    13744.64    10141.14    14913.13
#  17241.71334  7281.35     7686.84    14879.11     7849.53     7715.57
#   8412.88    12957.66    15934.15334 10126.87     7117.38    32761.36
#   9470.04    16971.3      6073.85    37381.8      6117.26   ]

# %%
testing_data_model_score = model2.score(x_test, y_test)
print("Model Score/Performance on Testing data",testing_data_model_score)

training_data_model_score = model2.score(x_train, y_train)
print("Model Score/Performance on Training data",training_data_model_score)
# Out:
# Model Score/Performance on Testing data 0.9048564739162297
# Model Score/Performance on Training data 0.9907108903232087

# %%
df = pd.DataFrame(data={'Predicted value':test_data_prediction2,'Actual Value':y_test})
df
# Out:
#      Predicted value  Actual Value
# 52        5949.26000        6795.0
# 181      16348.26167       15750.0
# 5        14447.30000       15250.0
# 18        6031.00000        5151.0
# 188       9645.03000        9995.0
# 170      14529.51000       11199.0
# 76        5960.81000        5389.0
# 154       7599.47000        7898.0
# 104      18111.27501       17199.0
# 33        6713.20000        6529.0
# 12       19363.57000       20970.0
# 129      35765.48000       31400.5
# 55       12419.68000       10945.0
# 66       14392.47000       18344.0
# 45        6357.65000        8916.5
# 169      13317.46000        9989.0
# 130      12210.14000        9295.0
# 7        18405.93167       18920.0
# 37        8576.26000        7895.0
# 152       6565.21000        6488.0
# 80        9395.88000        9959.0
# 111      13744.64000       15580.0
# 131      10141.14000        9895.0
# 171      14913.13000       11549.0
# 179      17241.71334       15998.0
# 138       7281.35000        5118.0
# ...

# %% [markdown]
# # Model Evaluation(RFC):

# %%
from sklearn.metrics import r2_score
r2Score = r2_score(test_data_prediction2, y_test)
print("R2 score of model is :" ,r2Score*100)
# Out:
# R2 score of model is : 86.91583033259086

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(test_data_prediction2,y_test)
print("Mean Absolute Error is :" ,mae)
# Out:
# Mean Absolute Error is : 1867.480853902439

# %% [markdown]
# Conclusion
#
# So, the mean absolute error is 1867.480853902439. Therefore our predicted value can be 1867.480853902439
#  units greater than or less than the actual value.

# %% [markdown]
# # 3) XGBRegressor(Extreme Gradient Boosting)

# %%
from xgboost import XGBRegressor
model = XGBRegressor()
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
test_data_prediction=model.predict(x_test)

# %%
print(test_data_prediction)
# Out:
# [ 6062.315  16436.965  12483.024   8607.949  10038.932  13368.531
#   6023.8916  6885.746  18634.178   6272.4756 21076.326  37178.215
#  11846.98   14568.255   6397.986  12205.556  12342.02   18807.652
#   8994.833   6147.6235  9143.627  16102.957   9818.865  13829.381
#  17682.25    7088.1714  8510.371  14525.625   7641.9727  7493.895
#   8311.096  12140.209  15899.997  10271.542   6862.458  32657.924
#   9992.617  18561.186   6130.741  38056.652   6271.61  ]

# %%
testing_data_model_score = model.score(x_test, y_test)
print("Model Score/Performance on Testing data",testing_data_model_score)

training_data_model_score = model.score(x_train, y_train)
print("Model Score/Performance on Training data",training_data_model_score)
# Out:
# Model Score/Performance on Testing data 0.90493839732248
# Model Score/Performance on Training data 0.9999999439625338

# %%
df = pd.DataFrame(data={'Predicted value':test_data_prediction,'Actual Value':y_test})
df
# Out:
#      Predicted value  Actual Value
# 52       6062.314941        6795.0
# 181     16436.964844       15750.0
# 5       12483.024414       15250.0
# 18       8607.949219        5151.0
# 188     10038.931641        9995.0
# 170     13368.531250       11199.0
# 76       6023.891602        5389.0
# 154      6885.746094        7898.0
# 104     18634.177734       17199.0
# 33       6272.475586        6529.0
# 12      21076.326172       20970.0
# 129     37178.214844       31400.5
# 55      11846.980469       10945.0
# 66      14568.254883       18344.0
# 45       6397.985840        8916.5
# 169     12205.555664        9989.0
# 130     12342.019531        9295.0
# 7       18807.652344       18920.0
# 37       8994.833008        7895.0
# 152      6147.623535        6488.0
# 80       9143.626953        9959.0
# 111     16102.957031       15580.0
# 131      9818.865234        9895.0
# 171     13829.380859       11549.0
# 179     17682.250000       15998.0
# 138      7088.171387        5118.0
# ...

# %% [markdown]
# # Model Evaluation (XGBRegressor)

# %%
from sklearn.metrics import r2_score
r2Score = r2_score(test_data_prediction, y_test)
print("R2 score of model is :" ,r2Score*100)
# Out:
# R2 score of model is : 87.64916430918764

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(test_data_prediction,y_test)
print("Mean Absolute Error is :" ,mae)
# Out:
# Mean Absolute Error is : 1847.3235280106708

# %% [markdown]
# Conclusion
#
# So, the mean absolute error is 1847.3235280106708. Therefore our predicted value can be 1847.3235280106708 units greater than or less than the actual value.
